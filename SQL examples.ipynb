# %% [markdown]
# # 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 12

# %% [markdown]
# ![image.png](attachment:image.png)
